# %%
import pandas as pd
df = pd.read_csv("C:/Users/Dawit Shibabaw/Desktop/big data proj/data_cancer.csv")
print(df.shape)
df.head()
# Out:
# (569, 16)
#    Unnamed: 0  diagnosis  radius_mean  perimeter_mean  area_mean  \
# 0           0          1           17             122       1001
# 1           1          1           20             132       1326
# 2           2          1           19             130       1203
# 3           3          1           11              77        386
# 4           4          1           20             135       1297
#
#    concave points_mean  fractal_dimension_mean  radius_se  texture_se  \
# 0                    1                       1          1           0
# 1                    1                       1          0           0
# 2                    1                       1          0           0
# 3                    1                       1          0           1
# 4                    1                       1          0           0
#
#    area_se  concavity_se  concave points_se  texture_worst  perimeter_worst  \
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'diagnosis', 'radius_mean', 'perimeter_mean', 'area_mean',
#        'concave points_mean', 'fractal_dimension_mean', 'radius_se',
#        'texture_se', 'area_se', 'concavity_se', 'concave points_se',
#        'texture_worst', 'perimeter_worst', 'area_worst', 'compactness_worst'],
#       dtype='object')

# %%
#dacolumnst.dropna()
#dataset['v013'].fillna(dataset['v013'].mode()[0], inplace=True)
df.drop(['Unnamed: 0'],axis=1, inplace=True)
df
# Out:
#      diagnosis  radius_mean  perimeter_mean  area_mean  concave points_mean  \
# 0            1           17             122       1001                    1
# 1            1           20             132       1326                    1
# 2            1           19             130       1203                    1
# 3            1           11              77        386                    1
# 4            1           20             135       1297                    1
# ..         ...          ...             ...        ...                  ...
# 564          1           21             142       1479                    0
# 565          1           20             131       1261                    0
# 566          1           16             108        858                    0
# 567          1           20             140       1265                    0
# 568          0            7              47        181                    0
#
# ...

# %%
df.drop(['area_mean'],axis=1, inplace=True)
df
# Out:
#      diagnosis  radius_mean  perimeter_mean  concave points_mean  \
# 0            1           17             122                    1
# 1            1           20             132                    1
# 2            1           19             130                    1
# 3            1           11              77                    1
# 4            1           20             135                    1
# ..         ...          ...             ...                  ...
# 564          1           21             142                    0
# 565          1           20             131                    0
# 566          1           16             108                    0
# 567          1           20             140                    0
# 568          0            7              47                    0
#
#      fractal_dimension_mean  radius_se  texture_se  area_se  concavity_se  \
# 0                         1          1           0      153             1
# ...

# %%
df.columns
# Out:
# Index(['diagnosis', 'radius_mean', 'perimeter_mean', 'concave points_mean',
#        'fractal_dimension_mean', 'radius_se', 'texture_se', 'area_se',
#        'concavity_se', 'concave points_se', 'texture_worst', 'perimeter_worst',
#        'area_worst', 'compactness_worst'],
#       dtype='object')

# %%
df['perimeter_mean'].value_counts()
# Out:
# perimeter_mean
# 73     20
# 82     20
# 78     20
# 88     18
# 87     17
#        ..
# 158     1
# 125     1
# 153     1
# 188     1
# 48      1
# Name: count, Length: 105, dtype: int64

# %%
df.loc[df.area_worst ==553 ,'area_worst'] = 709;
df.loc[df.area_worst ==564 ,'area_worst'] = 709;
df.loc[df.area_worst ==567 ,'area_worst'] = 830;
df.loc[df.area_worst ==546 ,'area_worst'] = 830;
df.loc[df.area_worst ==624 ,'area_worst'] = 709;
df.loc[df.area_worst ==706 ,'area_worst'] = 830;
df.loc[df.area_worst ==476 ,'area_worst'] = 709;
df.loc[df.area_worst ==472 ,'area_worst'] = 709;
df.loc[df.area_worst ==489 ,'area_worst'] = 830;
df.loc[df.area_worst ==467 ,'area_worst'] = 830;
df.loc[df.area_worst ==549 ,'area_worst'] = 709;

df.loc[df.area_worst ==515 ,'area_worst'] = 709;
df.loc[df.area_worst ==591 ,'area_worst'] = 709;
df.loc[df.area_worst ==809 ,'area_worst'] = 830;
df.loc[df.area_worst ==380 ,'area_worst'] = 830;
df.loc[df.area_worst ==440 ,'area_worst'] = 709;

df.loc[df.area_worst ==749 ,'area_worst'] = 709;
df.loc[df.area_worst ==826 ,'area_worst'] = 709;
df.loc[df.area_worst ==547 ,'area_worst'] = 830;
df.loc[df.area_worst ==521 ,'area_worst'] = 830;
df.loc[df.area_worst ==544 ,'area_worst'] = 709;

# %%
df.loc[df.area_worst ==819 ,'area_worst'] = 709;
df.loc[df.area_worst ==357 ,'area_worst'] = 709;
df.loc[df.area_worst ==698 ,'area_worst'] = 830;
df.loc[df.area_worst ==527 ,'area_worst'] = 830;
df.loc[df.area_worst ==808 ,'area_worst'] = 709;

df.loc[df.area_worst ==384 ,'area_worst'] = 709;
df.loc[df.area_worst ==523 ,'area_worst'] = 709;
df.loc[df.area_worst ==711 ,'area_worst'] = 830;
df.loc[df.area_worst ==1269 ,'area_worst'] = 830;
df.loc[df.area_worst ==513 ,'area_worst'] = 709;

df.loc[df.area_worst ==562 ,'area_worst'] = 709;
df.loc[df.area_worst ==739 ,'area_worst'] = 709;
df.loc[df.area_worst ==862 ,'area_worst'] = 830;
df.loc[df.area_worst ==284 ,'area_worst'] = 830;
df.loc[df.area_worst ==436 ,'area_worst'] = 709;

df.loc[df.area_worst ==475 ,'area_worst'] = 709;
df.loc[df.area_worst ==595 ,'area_worst'] = 709;
df.loc[df.area_worst ==585 ,'area_worst'] = 830;
df.loc[df.area_worst ==762 ,'area_worst'] = 830;
df.loc[df.area_worst ==888 ,'area_worst'] = 709;

# %%
df.loc[df.area_worst ==496 ,'area_worst'] = 709;
df.loc[df.area_worst ==622 ,'area_worst'] = 709;
df.loc[df.area_worst ==1623 ,'area_worst'] = 830;
df.loc[df.area_worst ==670 ,'area_worst'] = 830;
df.loc[df.area_worst ==533 ,'area_worst'] = 709;

df.loc[df.area_worst ==915 ,'area_worst'] = 709;
df.loc[df.area_worst ==677 ,'area_worst'] = 709;
df.loc[df.area_worst ==574 ,'area_worst'] = 830;
df.loc[df.area_worst ==543 ,'area_worst'] = 830;
df.loc[df.area_worst ==1603 ,'area_worst'] = 709;

df.loc[df.area_worst ==439 ,'area_worst'] = 709;
df.loc[df.area_worst ==653 ,'area_worst'] = 709;
df.loc[df.area_worst ==495 ,'area_worst'] = 830;
df.loc[df.area_worst ==1750 ,'area_worst'] = 830;
df.loc[df.area_worst ==803 ,'area_worst'] = 709;

df.loc[df.area_worst ==621 ,'area_worst'] = 709;
df.loc[df.area_worst ==458 ,'area_worst'] = 709;
df.loc[df.area_worst ==330 ,'area_worst'] = 830;
df.loc[df.area_worst ==284 ,'area_worst'] = 830;
df.loc[df.area_worst ==605 ,'area_worst'] = 709;

# %%
df.loc[df.area_worst ==580 ,'area_worst'] = 709;
df.loc[df.area_worst ==457 ,'area_worst'] = 709;
df.loc[df.area_worst ==1261 ,'area_worst'] = 830;
df.loc[df.area_worst ==740 ,'area_worst'] = 830;
df.loc[df.area_worst ==516 ,'area_worst'] = 709;

df.loc[df.area_worst ==376 ,'area_worst'] = 709;
df.loc[df.area_worst ==684 ,'area_worst'] = 709;
df.loc[df.area_worst ==661 ,'area_worst'] = 830;
df.loc[df.area_worst ==928 ,'area_worst'] = 830;
df.loc[df.area_worst ==508 ,'area_worst'] = 709;

# %%
df.loc[df.area_worst ==688 ,'area_worst'] = 709;
df.loc[df.area_worst ==750 ,'area_worst'] = 709;
df.loc[df.area_worst ==639 ,'area_worst'] = 830;
df.loc[df.area_worst ==390 ,'area_worst'] = 830;
df.loc[df.area_worst ==470 ,'area_worst'] = 709;

df.loc[df.area_worst ==633 ,'area_worst'] = 709;
df.loc[df.area_worst ==708 ,'area_worst'] = 709;
df.loc[df.area_worst ==375 ,'area_worst'] = 830;
df.loc[df.area_worst ==686 ,'area_worst'] = 830;
df.loc[df.area_worst ==545 ,'area_worst'] = 709;

df.loc[df.area_worst ==733 ,'area_worst'] = 709;
df.loc[df.area_worst ==906 ,'area_worst'] = 709;
df.loc[df.area_worst ==745 ,'area_worst'] = 830;
df.loc[df.area_worst ==632 ,'area_worst'] = 830;
df.loc[df.area_worst ==725 ,'area_worst'] = 709;

# %%
df.loc[df.area_worst ==783 ,'area_worst'] = 709;
df.loc[df.area_worst ==534 ,'area_worst'] = 709;
df.loc[df.area_worst ==552 ,'area_worst'] = 830;
df.loc[df.area_worst ==402 ,'area_worst'] = 830;
df.loc[df.area_worst ==583 ,'area_worst'] = 709;

df.loc[df.area_worst ==788 ,'area_worst'] = 709;
df.loc[df.area_worst ==856 ,'area_worst'] = 709;
df.loc[df.area_worst ==1760 ,'area_worst'] = 830;
df.loc[df.area_worst ==1600 ,'area_worst'] = 830;
df.loc[df.area_worst ==607 ,'area_worst'] = 709;

df.loc[df.area_worst ==1030 ,'area_worst'] = 709;
df.loc[df.area_worst ==1321 ,'area_worst'] = 709;
df.loc[df.area_worst ==1084 ,'area_worst'] = 830;
df.loc[df.area_worst ==1426 ,'area_worst'] = 830;
df.loc[df.area_worst ==648 ,'area_worst'] = 709;

# %%
df.loc[df.area_worst ==1740 ,'area_worst'] = 709;
df.loc[df.area_worst ==939 ,'area_worst'] = 709;
df.loc[df.area_worst ==660 ,'area_worst'] = 830;
df.loc[df.area_worst ==854 ,'area_worst'] = 830;
df.loc[df.area_worst ==831 ,'area_worst'] = 709;

df.loc[df.area_worst ==558 ,'area_worst'] = 709;
df.loc[df.area_worst ==421 ,'area_worst'] = 709;
df.loc[df.area_worst ==433 ,'area_worst'] = 830;
df.loc[df.area_worst ==828 ,'area_worst'] = 830;
df.loc[df.area_worst ==718 ,'area_worst'] = 709;

df.loc[df.area_worst ==687 ,'area_worst'] = 709;
df.loc[df.area_worst ==907 ,'area_worst'] = 709;
df.loc[df.area_worst ==2145 ,'area_worst'] = 830;
df.loc[df.area_worst ==274 ,'area_worst'] = 830;
df.loc[df.area_worst ==310 ,'area_worst'] = 709;

df.loc[df.area_worst ==242 ,'area_worst'] = 709;
df.loc[df.area_worst ==582 ,'area_worst'] = 709;
df.loc[df.area_worst ==759 ,'area_worst'] = 830;
df.loc[df.area_worst ==506 ,'area_worst'] = 830;
df.loc[df.area_worst ==1567 ,'area_worst'] = 709;

# %%
df.loc[df.area_worst ==1651 ,'area_worst'] = 709;
df.loc[df.area_worst ==385 ,'area_worst'] = 709;
df.loc[df.area_worst ==528 ,'area_worst'] = 830;
df.loc[df.area_worst ==689 ,'area_worst'] = 830;
df.loc[df.area_worst ==897 ,'area_worst'] = 709;

df.loc[df.area_worst ==985 ,'area_worst'] = 709;
df.loc[df.area_worst ==368 ,'area_worst'] = 709;
df.loc[df.area_worst ==734 ,'area_worst'] = 830;
df.loc[df.area_worst ==273 ,'area_worst'] = 830;
df.loc[df.area_worst ==959 ,'area_worst'] = 709;


df.loc[df.area_worst ==514 ,'area_worst'] = 709;
df.loc[df.area_worst ==4254 ,'area_worst'] = 709;
df.loc[df.area_worst ==520 ,'area_worst'] = 830;
df.loc[df.area_worst ==1748 ,'area_worst'] = 830;
df.loc[df.area_worst ==787 ,'area_worst'] = 709;

df.loc[df.area_worst ==1648 ,'area_worst'] = 709;
df.loc[df.area_worst ==349 ,'area_worst'] = 709;
df.loc[df.area_worst ==628 ,'area_worst'] = 830;
df.loc[df.area_worst ==507 ,'area_worst'] = 830;
df.loc[df.area_worst ==586 ,'area_worst'] = 709;

df.loc[df.area_worst ==301 ,'area_worst'] = 709;
df.loc[df.area_worst ==705 ,'area_worst'] = 709;
df.loc[df.area_worst ==1421 ,'area_worst'] = 830;
df.loc[df.area_worst ==505 ,'area_worst'] = 830;
df.loc[df.area_worst ==869 ,'area_worst'] = 709;

# %%
df.loc[df.area_worst ==566 ,'area_worst'] = 709;
df.loc[df.area_worst ==2022 ,'area_worst'] = 709;
df.loc[df.area_worst ==777 ,'area_worst'] = 830;
df.loc[df.area_worst ==1479 ,'area_worst'] = 830;
df.loc[df.area_worst ==832 ,'area_worst'] = 709;

df.loc[df.area_worst ==1709 ,'area_worst'] = 709;
df.loc[df.area_worst ==829 ,'area_worst'] = 709;
df.loc[df.area_worst ==1292 ,'area_worst'] = 830;
df.loc[df.area_worst ==1284 ,'area_worst'] = 830;
df.loc[df.area_worst ==626 ,'area_worst'] = 709;

# %%
df.loc[df.area_worst ==366 ,'area_worst'] = 709;
df.loc[df.area_worst ==799 ,'area_worst'] = 709;
df.loc[df.area_worst ==1229 ,'area_worst'] = 830;
df.loc[df.area_worst ==1349 ,'area_worst'] = 830;
df.loc[df.area_worst ==610 ,'area_worst'] = 709;

df.loc[df.area_worst ==656 ,'area_worst'] = 709;
df.loc[df.area_worst ==867 ,'area_worst'] = 709;
df.loc[df.area_worst ==931 ,'area_worst'] = 830;
df.loc[df.area_worst ==522 ,'area_worst'] = 830;
df.loc[df.area_worst ==359 ,'area_worst'] = 709;

df.loc[df.area_worst ==1606 ,'area_worst'] = 709;
df.loc[df.area_worst ==741 ,'area_worst'] = 709;
df.loc[df.area_worst ==1575 ,'area_worst'] = 830;
df.loc[df.area_worst ==1304 ,'area_worst'] = 830;
df.loc[df.area_worst ==645 ,'area_worst'] = 709;

# %%
df.loc[df.area_worst ==471 ,'area_worst'] = 709;
df.loc[df.area_worst ==1813 ,'area_worst'] = 709;
df.loc[df.area_worst ==317 ,'area_worst'] = 830;
df.loc[df.area_worst ==2081 ,'area_worst'] = 830;
df.loc[df.area_worst ==675 ,'area_worst'] = 709;

df.loc[df.area_worst ==1249 ,'area_worst'] = 709;
df.loc[df.area_worst ==1344 ,'area_worst'] = 709;
df.loc[df.area_worst ==623 ,'area_worst'] = 830;
df.loc[df.area_worst ==529 ,'area_worst'] = 830;
df.loc[df.area_worst ==1313 ,'area_worst'] = 709;

df.loc[df.area_worst ==947 ,'area_worst'] = 709;
df.loc[df.area_worst ==1670 ,'area_worst'] = 709;
df.loc[df.area_worst ==1227 ,'area_worst'] = 830;
df.loc[df.area_worst ==657 ,'area_worst'] = 830;
df.loc[df.area_worst ==447 ,'area_worst'] = 709;

# %%
df.loc[df.area_worst ==589 ,'area_worst'] = 709;
df.loc[df.area_worst ==1403 ,'area_worst'] = 709;
df.loc[df.area_worst ==861 ,'area_worst'] = 830;
df.loc[df.area_worst ==351 ,'area_worst'] = 830;
df.loc[df.area_worst ==680 ,'area_worst'] = 709;

df.loc[df.area_worst ==559 ,'area_worst'] = 709;
df.loc[df.area_worst ==896 ,'area_worst'] = 709;
df.loc[df.area_worst ==1165 ,'area_worst'] = 830;
df.loc[df.area_worst ==1535 ,'area_worst'] = 830;
df.loc[df.area_worst ==1946 ,'area_worst'] = 709;

df.loc[df.area_worst ==1359 ,'area_worst'] = 709;
df.loc[df.area_worst ==1461 ,'area_worst'] = 709;
df.loc[df.area_worst ==1671 ,'area_worst'] = 830;
df.loc[df.area_worst ==3143 ,'area_worst'] = 830;
df.loc[df.area_worst ==2227 ,'area_worst'] = 709;

df.loc[df.area_worst ==394 ,'area_worst'] = 709;
df.loc[df.area_worst ==2215 ,'area_worst'] = 709;
df.loc[df.area_worst ==2615 ,'area_worst'] = 830;
df.loc[df.area_worst ==663 ,'area_worst'] = 830;
df.loc[df.area_worst ==1780 ,'area_worst'] = 709;

# %%
df.loc[df.area_worst ==450 ,'area_worst'] = 709;
df.loc[df.area_worst ==980 ,'area_worst'] = 709;
df.loc[df.area_worst ==314 ,'area_worst'] = 830;
df.loc[df.area_worst ==1150 ,'area_worst'] = 830;
df.loc[df.area_worst ==1009 ,'area_worst'] = 709;

df.loc[df.area_worst ==758 ,'area_worst'] = 709;
df.loc[df.area_worst ==630 ,'area_worst'] = 709;
df.loc[df.area_worst ==694 ,'area_worst'] = 830;
df.loc[df.area_worst ==302 ,'area_worst'] = 830;
df.loc[df.area_worst ==1299 ,'area_worst'] = 709;

df.loc[df.area_worst ==488 ,'area_worst'] = 709;
df.loc[df.area_worst ==2398 ,'area_worst'] = 709;
df.loc[df.area_worst ==876 ,'area_worst'] = 830;
df.loc[df.area_worst ==1332 ,'area_worst'] = 830;
df.loc[df.area_worst ==453 ,'area_worst'] = 709;

# %%
df.loc[df.area_worst ==2019 ,'area_worst'] = 709;
df.loc[df.area_worst ==1315 ,'area_worst'] = 709;
df.loc[df.area_worst ==1138 ,'area_worst'] = 830;
df.loc[df.area_worst ==943 ,'area_worst'] = 830;
df.loc[df.area_worst ==697 ,'area_worst'] = 709;

df.loc[df.area_worst ==2782 ,'area_worst'] = 709;
df.loc[df.area_worst ==1050 ,'area_worst'] = 709;
df.loc[df.area_worst ==3234 ,'area_worst'] = 830;
df.loc[df.area_worst ==466 ,'area_worst'] = 830;
df.loc[df.area_worst ==925 ,'area_worst'] = 709;

df.loc[df.area_worst ==300 ,'area_worst'] = 709;
df.loc[df.area_worst ==542 ,'area_worst'] = 709;
df.loc[df.area_worst ==880 ,'area_worst'] = 830;
df.loc[df.area_worst ==554 ,'area_worst'] = 830;
df.loc[df.area_worst ==324 ,'area_worst'] = 709;

# %%
df.loc[df.area_worst ==328 ,'area_worst'] = 709;
df.loc[df.area_worst ==1540 ,'area_worst'] = 709;
df.loc[df.area_worst ==353 ,'area_worst'] = 830;
df.loc[df.area_worst ==1681 ,'area_worst'] = 830;
df.loc[df.area_worst ==1866 ,'area_worst'] = 709;

df.loc[df.area_worst ==411 ,'area_worst'] = 709;
df.loc[df.area_worst ==2906 ,'area_worst'] = 709;
df.loc[df.area_worst ==1873 ,'area_worst'] = 830;
df.loc[df.area_worst ==611 ,'area_worst'] = 830;
df.loc[df.area_worst ==827 ,'area_worst'] = 709;

df.loc[df.area_worst ==909 ,'area_worst'] = 709;
df.loc[df.area_worst ==576 ,'area_worst'] = 709;
df.loc[df.area_worst ==1362 ,'area_worst'] = 830;
df.loc[df.area_worst ==492 ,'area_worst'] = 830;
df.loc[df.area_worst ==1223 ,'area_worst'] = 709;

df.loc[df.area_worst ==473 ,'area_worst'] = 709;
df.loc[df.area_worst ==634 ,'area_worst'] = 709;
df.loc[df.area_worst ==614 ,'area_worst'] = 830;
df.loc[df.area_worst ==525 ,'area_worst'] = 830;
df.loc[df.area_worst ==1610 ,'area_worst'] = 709;

# %%
df.loc[df.area_worst ==760 ,'area_worst'] = 709;
df.loc[df.area_worst ==1070 ,'area_worst'] = 709;
df.loc[df.area_worst ==975 ,'area_worst'] = 830;
df.loc[df.area_worst ==1121 ,'area_worst'] = 830;
df.loc[df.area_worst ==2562 ,'area_worst'] = 709;

df.loc[df.area_worst ==844 ,'area_worst'] = 709;
df.loc[df.area_worst ==1938 ,'area_worst'] = 709;
df.loc[df.area_worst ==599 ,'area_worst'] = 830;
df.loc[df.area_worst ==699 ,'area_worst'] = 830;
df.loc[df.area_worst ==1298 ,'area_worst'] = 709;

df.loc[df.area_worst ==967 ,'area_worst'] = 709;
df.loc[df.area_worst ==1657 ,'area_worst'] = 709;
df.loc[df.area_worst ==297 ,'area_worst'] = 830;
df.loc[df.area_worst ==512 ,'area_worst'] = 830;
df.loc[df.area_worst ==1025 ,'area_worst'] = 709;

df.loc[df.area_worst ==478 ,'area_worst'] = 709;
df.loc[df.area_worst ==1485 ,'area_worst'] = 709;
df.loc[df.area_worst ==240 ,'area_worst'] = 830;
df.loc[df.area_worst ==361 ,'area_worst'] = 830;
df.loc[df.area_worst ==185 ,'area_worst'] = 709;

df.loc[df.area_worst ==1493 ,'area_worst'] = 709;
df.loc[df.area_worst ==2360 ,'area_worst'] = 709;
df.loc[df.area_worst ==618 ,'area_worst'] = 830;
df.loc[df.area_worst ==840 ,'area_worst'] = 830;
df.loc[df.area_worst ==827 ,'area_worst'] = 709;

# %%
df.loc[df.area_worst ==1646 ,'area_worst'] = 709;
df.loc[df.area_worst ==483 ,'area_worst'] = 709;
df.loc[df.area_worst ==672 ,'area_worst'] = 830;
df.loc[df.area_worst ==1696 ,'area_worst'] = 830;
df.loc[df.area_worst ==518 ,'area_worst'] = 830;

df.loc[df.area_worst ==674 ,'area_worst'] = 709;
df.loc[df.area_worst ==285 ,'area_worst'] = 709;
df.loc[df.area_worst ==270 ,'area_worst'] = 830;
df.loc[df.area_worst ==374 ,'area_worst'] = 830;
df.loc[df.area_worst ==367 ,'area_worst'] = 830;

df.loc[df.area_worst ==326 ,'area_worst'] = 709;
df.loc[df.area_worst ==636 ,'area_worst'] = 709;
df.loc[df.area_worst ==2053 ,'area_worst'] = 830;
df.loc[df.area_worst ==1272 ,'area_worst'] = 830;
df.loc[df.area_worst ==1095 ,'area_worst'] = 830;

df.loc[df.area_worst ==2642 ,'area_worst'] = 709;
df.loc[df.area_worst ==551 ,'area_worst'] = 709;
df.loc[df.area_worst ==362 ,'area_worst'] = 830;
df.loc[df.area_worst ==1549 ,'area_worst'] = 830;
df.loc[df.area_worst ==510 ,'area_worst'] = 830;

# %%
df.loc[df.area_worst ==435 ,'area_worst'] = 709;
df.loc[df.area_worst ==1956 ,'area_worst'] = 709;
df.loc[df.area_worst ==392 ,'area_worst'] = 830;
df.loc[df.area_worst ==517 ,'area_worst'] = 830;
df.loc[df.area_worst ==2073 ,'area_worst'] = 830;

df.loc[df.area_worst ==701 ,'area_worst'] = 709;
df.loc[df.area_worst ==767 ,'area_worst'] = 709;
df.loc[df.area_worst ==1589 ,'area_worst'] = 830;
df.loc[df.area_worst ==1538 ,'area_worst'] = 830;
df.loc[df.area_worst ==848 ,'area_worst'] = 830;

df.loc[df.area_worst ==275 ,'area_worst'] = 709;
df.loc[df.area_worst ==459 ,'area_worst'] = 709;
df.loc[df.area_worst ==922 ,'area_worst'] = 830;
df.loc[df.area_worst ==1175 ,'area_worst'] = 830;
df.loc[df.area_worst ==1156 ,'area_worst'] = 830;

df.loc[df.area_worst ==719 ,'area_worst'] = 709;
df.loc[df.area_worst ==577 ,'area_worst'] = 709;
df.loc[df.area_worst ==1031 ,'area_worst'] = 830;
df.loc[df.area_worst ==462 ,'area_worst'] = 830;
df.loc[df.area_worst ==1590 ,'area_worst'] = 830;

# %%
df.loc[df.area_worst ==550 ,'area_worst'] = 709;
df.loc[df.area_worst ==1628 ,'area_worst'] = 709;
df.loc[df.area_worst ==1724 ,'area_worst'] = 830;
df.loc[df.area_worst ==434 ,'area_worst'] = 830;
df.loc[df.area_worst ==971 ,'area_worst'] = 830;

df.loc[df.area_worst ==773 ,'area_worst'] = 709;
df.loc[df.area_worst ==1236 ,'area_worst'] = 709;
df.loc[df.area_worst ==1320 ,'area_worst'] = 830;
df.loc[df.area_worst ==1233 ,'area_worst'] = 830;
df.loc[df.area_worst ==342 ,'area_worst'] = 830;

df.loc[df.area_worst ==1645 ,'area_worst'] = 709;
df.loc[df.area_worst ==355 ,'area_worst'] = 709;
df.loc[df.area_worst ==1417 ,'area_worst'] = 830;
df.loc[df.area_worst ==643 ,'area_worst'] = 830;
df.loc[df.area_worst ==503 ,'area_worst'] = 830;

df.loc[df.area_worst ==407 ,'area_worst'] = 709;
df.loc[df.area_worst ==2384 ,'area_worst'] = 709;
df.loc[df.area_worst ==410 ,'area_worst'] = 830;
df.loc[df.area_worst ==597 ,'area_worst'] = 830;
df.loc[df.area_worst ==602 ,'area_worst'] = 830;

df.loc[df.area_worst ==1809 ,'area_worst'] = 709;
df.loc[df.area_worst ==424 ,'area_worst'] = 709;
df.loc[df.area_worst ==3432 ,'area_worst'] = 830;
df.loc[df.area_worst ==491 ,'area_worst'] = 830;
df.loc[df.area_worst ==455 ,'area_worst'] = 830;

# %%
df.loc[df.area_worst ==728 ,'area_worst'] = 709;
df.loc[df.area_worst ==1436 ,'area_worst'] = 709;
df.loc[df.area_worst ==1222 ,'area_worst'] = 830;
df.loc[df.area_worst ==1933 ,'area_worst'] = 830;
df.loc[df.area_worst ==2010 ,'area_worst'] = 830;

df.loc[df.area_worst ==487 ,'area_worst'] = 709;
df.loc[df.area_worst ==988 ,'area_worst'] = 709;
df.loc[df.area_worst ==1295 ,'area_worst'] = 830;
df.loc[df.area_worst ==1218 ,'area_worst'] = 830;
df.loc[df.area_worst ==1972 ,'area_worst'] = 830;

df.loc[df.area_worst ==248 ,'area_worst'] = 709;
df.loc[df.area_worst ==1844 ,'area_worst'] = 709;
df.loc[df.area_worst ==1035 ,'area_worst'] = 830;
df.loc[df.area_worst ==1226 ,'area_worst'] = 830;
df.loc[df.area_worst ==1926 ,'area_worst'] = 830;

# %%
df.loc[df.area_worst ==223 ,'area_worst'] = 709;
df.loc[df.area_worst ==441 ,'area_worst'] = 709;
df.loc[df.area_worst ==509 ,'area_worst'] = 830;
df.loc[df.area_worst ==766 ,'area_worst'] = 830;
df.loc[df.area_worst ==683 ,'area_worst'] = 830;

df.loc[df.area_worst ==629 ,'area_worst'] = 709;
df.loc[df.area_worst ==616 ,'area_worst'] = 709;
df.loc[df.area_worst ==2944 ,'area_worst'] = 830;
df.loc[df.area_worst ==764 ,'area_worst'] = 830;
df.loc[df.area_worst ==1408 ,'area_worst'] = 830;

df.loc[df.area_worst ==729 ,'area_worst'] = 709;
df.loc[df.area_worst ==249 ,'area_worst'] = 709;
df.loc[df.area_worst ==1302 ,'area_worst'] = 830;
df.loc[df.area_worst ==335 ,'area_worst'] = 830;
df.loc[df.area_worst ==715 ,'area_worst'] = 830;

df.loc[df.area_worst ==364 ,'area_worst'] = 709;
df.loc[df.area_worst ==1032 ,'area_worst'] = 709;
df.loc[df.area_worst ==532 ,'area_worst'] = 830;
df.loc[df.area_worst ==452 ,'area_worst'] = 830;
df.loc[df.area_worst ==1872 ,'area_worst'] = 830;

# %%
df.loc[df.area_worst ==505 ,'area_worst'] = 709;
df.loc[df.area_worst ==1495 ,'area_worst'] = 709;
df.loc[df.area_worst ==873 ,'area_worst'] = 830;
df.loc[df.area_worst ==395 ,'area_worst'] = 830;
df.loc[df.area_worst ==1189 ,'area_worst'] = 830;

# %%
df.loc[df.area_worst ==412 ,'area_worst'] = 709;
df.loc[df.area_worst ==2232 ,'area_worst'] = 709;
df.loc[df.area_worst ==2403 ,'area_worst'] = 830;
df.loc[df.area_worst ==2477 ,'area_worst'] = 830;
df.loc[df.area_worst ==1088 ,'area_worst'] = 830;

df.loc[df.area_worst ==594 ,'area_worst'] = 709;
df.loc[df.area_worst ==782 ,'area_worst'] = 709;
df.loc[df.area_worst ==414 ,'area_worst'] = 830;
df.loc[df.area_worst ==403 ,'area_worst'] = 830;
df.loc[df.area_worst ==2009 ,'area_worst'] = 830;

df.loc[df.area_worst ==295 ,'area_worst'] = 709;
df.loc[df.area_worst ==1260 ,'area_worst'] = 709;
df.loc[df.area_worst ==1021 ,'area_worst'] = 830;
df.loc[df.area_worst ==811 ,'area_worst'] = 830;
df.loc[df.area_worst ==531 ,'area_worst'] = 830;

df.loc[df.area_worst ==347 ,'area_worst'] = 709;
df.loc[df.area_worst ==1660 ,'area_worst'] = 709;
df.loc[df.area_worst ==1656 ,'area_worst'] = 830;
df.loc[df.area_worst ==2499 ,'area_worst'] = 830;
df.loc[df.area_worst ==1921 ,'area_worst'] = 830;

df.loc[df.area_worst ==474 ,'area_worst'] = 709;
df.loc[df.area_worst ==793 ,'area_worst'] = 709;
df.loc[df.area_worst ==993 ,'area_worst'] = 830;
df.loc[df.area_worst ==1102 ,'area_worst'] = 830;
df.loc[df.area_worst ==932 ,'area_worst'] = 830;

# %%
df.loc[df.area_worst ==1819 ,'area_worst'] = 709;
df.loc[df.area_worst ==396 ,'area_worst'] = 709;
df.loc[df.area_worst ==1986 ,'area_worst'] = 830;
df.loc[df.area_worst ==989 ,'area_worst'] = 830;
df.loc[df.area_worst ==331 ,'area_worst'] = 830;

df.loc[df.area_worst ==2027 ,'area_worst'] = 709;
df.loc[df.area_worst ==408 ,'area_worst'] = 709;
df.loc[df.area_worst ==1239 ,'area_worst'] = 830;
df.loc[df.area_worst ==1939 ,'area_worst'] = 830;
df.loc[df.area_worst ==1153 ,'area_worst'] = 830;

df.loc[df.area_worst ==1731 ,'area_worst'] = 709;
df.loc[df.area_worst ==259 ,'area_worst'] = 709;
df.loc[df.area_worst ==981 ,'area_worst'] = 830;
df.loc[df.area_worst ==1044 ,'area_worst'] = 830;
df.loc[df.area_worst ==638 ,'area_worst'] = 830;

df.loc[df.area_worst ==1124 ,'area_worst'] = 709;
df.loc[df.area_worst ==608 ,'area_worst'] = 709;
df.loc[df.area_worst ==570 ,'area_worst'] = 830;
df.loc[df.area_worst ==1228 ,'area_worst'] = 830;
df.loc[df.area_worst ==1688 ,'area_worst'] = 830;

df.loc[df.area_worst ==1821 ,'area_worst'] = 709;
df.loc[df.area_worst ==303 ,'area_worst'] = 709;
df.loc[df.area_worst ==768 ,'area_worst'] = 830;
df.loc[df.area_worst ==784 ,'area_worst'] = 830;
df.loc[df.area_worst ==806 ,'area_worst'] = 830;

df.loc[df.area_worst ==268 ,'area_worst'] = 709;
df.loc[df.area_worst ==3216 ,'area_worst'] = 709;
df.loc[df.area_worst ==2089 ,'area_worst'] = 830;
df.loc[df.area_worst ==973 ,'area_worst'] = 830;
df.loc[df.area_worst ==1410 ,'area_worst'] = 830;

# %%
df.loc[df.perimeter_worst ==97 ,'perimeter_worst'] = 86;
df.loc[df.perimeter_worst ==84 ,'perimeter_worst'] = 88;
df.loc[df.perimeter_worst ==79 ,'perimeter_worst'] = 87;
df.loc[df.perimeter_worst ==93 ,'perimeter_worst'] = 87;
df.loc[df.perimeter_worst ==114 ,'perimeter_worst'] = 88;

df.loc[df.perimeter_worst ==92 ,'perimeter_worst'] = 86;
df.loc[df.perimeter_worst ==85 ,'perimeter_worst'] = 88;
df.loc[df.perimeter_worst ==83 ,'perimeter_worst'] = 87;
df.loc[df.perimeter_worst ==82 ,'perimeter_worst'] = 87;
df.loc[df.perimeter_worst ==91 ,'perimeter_worst'] = 86;

df.loc[df.perimeter_worst ==89 ,'perimeter_worst'] = 86;
df.loc[df.perimeter_worst ==71 ,'perimeter_worst'] = 88;
df.loc[df.perimeter_worst ==113 ,'perimeter_worst'] = 87;
df.loc[df.perimeter_worst ==96 ,'perimeter_worst'] = 87;
df.loc[df.perimeter_worst ==99 ,'perimeter_worst'] = 86;

df.loc[df.perimeter_worst ==95 ,'perimeter_worst'] = 86;
df.loc[df.perimeter_worst ==102 ,'perimeter_worst'] = 88;
df.loc[df.perimeter_worst ==81 ,'perimeter_worst'] = 87;
df.loc[df.perimeter_worst ==101 ,'perimeter_worst'] = 87;
df.loc[df.perimeter_worst ==152 ,'perimeter_worst'] = 88;

df.loc[df.perimeter_worst ==108 ,'perimeter_worst'] = 86;
df.loc[df.perimeter_worst ==78 ,'perimeter_worst'] = 88;
df.loc[df.perimeter_worst ==69 ,'perimeter_worst'] = 87;
df.loc[df.perimeter_worst ==76 ,'perimeter_worst'] = 87;
df.loc[df.perimeter_worst ==129 ,'perimeter_worst'] = 88;

# %%
df.loc[df.perimeter_worst ==73 ,'perimeter_worst'] = 86;
df.loc[df.perimeter_worst ==104 ,'perimeter_worst'] = 88;
df.loc[df.perimeter_worst ==90 ,'perimeter_worst'] = 87;
df.loc[df.perimeter_worst ==105 ,'perimeter_worst'] = 87;
df.loc[df.perimeter_worst ==98 ,'perimeter_worst'] = 88;

df.loc[df.perimeter_worst ==110 ,'perimeter_worst'] = 86;
df.loc[df.perimeter_worst ==100 ,'perimeter_worst'] = 88;
df.loc[df.perimeter_worst ==68 ,'perimeter_worst'] = 87;
df.loc[df.perimeter_worst ==109 ,'perimeter_worst'] = 87;
df.loc[df.perimeter_worst ==94 ,'perimeter_worst'] = 88;

df.loc[df.perimeter_worst ==65 ,'perimeter_worst'] = 86;
df.loc[df.perimeter_worst ==107 ,'perimeter_worst'] = 88;
df.loc[df.perimeter_worst ==117 ,'perimeter_worst'] = 87;
df.loc[df.perimeter_worst ==115 ,'perimeter_worst'] = 87;
df.loc[df.perimeter_worst ==106 ,'perimeter_worst'] = 88;

# %%
df.loc[df.perimeter_worst ==112 ,'perimeter_worst'] = 86;
df.loc[df.perimeter_worst ==103 ,'perimeter_worst'] = 88;
df.loc[df.perimeter_worst ==123 ,'perimeter_worst'] = 87;
df.loc[df.perimeter_worst ==93 ,'perimeter_worst'] = 87;
df.loc[df.perimeter_worst ==114 ,'perimeter_worst'] = 88;

df.loc[df.perimeter_worst ==74 ,'perimeter_worst'] = 86;
df.loc[df.perimeter_worst ==70 ,'perimeter_worst'] = 88;
df.loc[df.perimeter_worst ==143 ,'perimeter_worst'] = 87;
df.loc[df.perimeter_worst ==80 ,'perimeter_worst'] = 87;
df.loc[df.perimeter_worst ==75 ,'perimeter_worst'] = 88;

df.loc[df.perimeter_worst ==77 ,'perimeter_worst'] = 86;
df.loc[df.perimeter_worst ==130 ,'perimeter_worst'] = 88;
df.loc[df.perimeter_worst ==160 ,'perimeter_worst'] = 87;
df.loc[df.perimeter_worst ==145 ,'perimeter_worst'] = 87;
df.loc[df.perimeter_worst ==62 ,'perimeter_worst'] = 88;

# %%
df.loc[df.perimeter_worst ==139 ,'perimeter_worst'] = 86;
df.loc[df.perimeter_worst ==67 ,'perimeter_worst'] = 88;
df.loc[df.perimeter_worst ==128 ,'perimeter_worst'] = 87;
df.loc[df.perimeter_worst ==119 ,'perimeter_worst'] = 87;
df.loc[df.perimeter_worst ==72 ,'perimeter_worst'] = 88;

df.loc[df.perimeter_worst ==166 ,'perimeter_worst'] = 86;
df.loc[df.perimeter_worst ==158 ,'perimeter_worst'] = 88;
df.loc[df.perimeter_worst ==146 ,'perimeter_worst'] = 87;
df.loc[df.perimeter_worst ==125 ,'perimeter_worst'] = 87;
df.loc[df.perimeter_worst ==161 ,'perimeter_worst'] = 88;

df.loc[df.perimeter_worst ==170 ,'perimeter_worst'] = 86;
df.loc[df.perimeter_worst ==126 ,'perimeter_worst'] = 88;
df.loc[df.perimeter_worst ==127 ,'perimeter_worst'] = 87;
df.loc[df.perimeter_worst ==66 ,'perimeter_worst'] = 87;
df.loc[df.perimeter_worst ==177 ,'perimeter_worst'] = 88;

df.loc[df.perimeter_worst ==184 ,'perimeter_worst'] = 86;
df.loc[df.perimeter_worst ==111 ,'perimeter_worst'] = 88;
df.loc[df.perimeter_worst ==150 ,'perimeter_worst'] = 87;
df.loc[df.perimeter_worst ==133 ,'perimeter_worst'] = 87;
df.loc[df.perimeter_worst ==132 ,'perimeter_worst'] = 88;

# %%
df.loc[df.perimeter_worst ==140 ,'perimeter_worst'] = 86;
df.loc[df.perimeter_worst ==159 ,'perimeter_worst'] = 88;
df.loc[df.perimeter_worst ==142 ,'perimeter_worst'] = 87;
df.loc[df.perimeter_worst ==136 ,'perimeter_worst'] = 87;
df.loc[df.perimeter_worst ==124 ,'perimeter_worst'] = 88;

df.loc[df.perimeter_worst ==148 ,'perimeter_worst'] = 86;
df.loc[df.perimeter_worst ==157 ,'perimeter_worst'] = 88;
df.loc[df.perimeter_worst ==153 ,'perimeter_worst'] = 87;
df.loc[df.perimeter_worst ==171 ,'perimeter_worst'] = 87;
df.loc[df.perimeter_worst ==195 ,'perimeter_worst'] = 88;

df.loc[df.perimeter_worst ==59 ,'perimeter_worst'] = 86;
df.loc[df.perimeter_worst ==188 ,'perimeter_worst'] = 88;
df.loc[df.perimeter_worst ==163 ,'perimeter_worst'] = 87;
df.loc[df.perimeter_worst ==151 ,'perimeter_worst'] = 87;
df.loc[df.perimeter_worst ==206 ,'perimeter_worst'] = 88;


df.loc[df.perimeter_worst ==162 ,'perimeter_worst'] = 86;
df.loc[df.perimeter_worst ==211 ,'perimeter_worst'] = 88;
df.loc[df.perimeter_worst ==122 ,'perimeter_worst'] = 87;
df.loc[df.perimeter_worst ==180 ,'perimeter_worst'] = 87;
df.loc[df.perimeter_worst ==141 ,'perimeter_worst'] = 88;

df.loc[df.perimeter_worst ==149 ,'perimeter_worst'] = 86;
df.loc[df.perimeter_worst ==120 ,'perimeter_worst'] = 88;
df.loc[df.perimeter_worst ==116 ,'perimeter_worst'] = 87;
df.loc[df.perimeter_worst ==165 ,'perimeter_worst'] = 87;
df.loc[df.perimeter_worst ==155 ,'perimeter_worst'] = 88;

# %%
df.loc[df.perimeter_worst ==63 ,'perimeter_worst'] = 86;
df.loc[df.perimeter_worst ==121 ,'perimeter_worst'] = 88;
df.loc[df.perimeter_worst ==135 ,'perimeter_worst'] = 87;
df.loc[df.perimeter_worst ==57 ,'perimeter_worst'] = 87;
df.loc[df.perimeter_worst ==58 ,'perimeter_worst'] = 88;

df.loc[df.perimeter_worst ==229 ,'perimeter_worst'] = 86;
df.loc[df.perimeter_worst ==202 ,'perimeter_worst'] = 88;
df.loc[df.perimeter_worst ==56 ,'perimeter_worst'] = 87;
df.loc[df.perimeter_worst ==214 ,'perimeter_worst'] = 87;
df.loc[df.perimeter_worst ==64 ,'perimeter_worst'] = 88;

df.loc[df.perimeter_worst ==251 ,'perimeter_worst'] = 86;
df.loc[df.perimeter_worst ==168 ,'perimeter_worst'] = 88;
df.loc[df.perimeter_worst ==138 ,'perimeter_worst'] = 87;
df.loc[df.perimeter_worst ==172 ,'perimeter_worst'] = 87;
df.loc[df.perimeter_worst ==199 ,'perimeter_worst'] = 88;

df.loc[df.perimeter_worst ==205 ,'perimeter_worst'] = 86;
df.loc[df.perimeter_worst ==220 ,'perimeter_worst'] = 88;
df.loc[df.perimeter_worst ==176 ,'perimeter_worst'] = 87;
df.loc[df.perimeter_worst ==156 ,'perimeter_worst'] = 87;
df.loc[df.perimeter_worst ==60 ,'perimeter_worst'] = 88;

df.loc[df.perimeter_worst ==54 ,'perimeter_worst'] = 86;
df.loc[df.perimeter_worst ==118 ,'perimeter_worst'] = 88;
df.loc[df.perimeter_worst ==144 ,'perimeter_worst'] = 87;
df.loc[df.perimeter_worst ==178 ,'perimeter_worst'] = 87;
df.loc[df.perimeter_worst ==137 ,'perimeter_worst'] = 88;

df.loc[df.perimeter_worst ==179 ,'perimeter_worst'] = 86;
df.loc[df.perimeter_worst ==186 ,'perimeter_worst'] = 88;
df.loc[df.perimeter_worst ==134 ,'perimeter_worst'] = 87;
df.loc[df.perimeter_worst ==50 ,'perimeter_worst'] = 87;
df.loc[df.perimeter_worst ==174 ,'perimeter_worst'] = 88;

# %%
df.loc[df.texture_worst ==24 ,'texture_worst'] = 25;
df.loc[df.texture_worst ==28 ,'texture_worst'] = 26;
df.loc[df.texture_worst ==21 ,'texture_worst'] = 22;
df.loc[df.texture_worst ==27 ,'texture_worst'] = 19;
df.loc[df.texture_worst ==23 ,'texture_worst'] = 19;

df.loc[df.texture_worst ==29 ,'texture_worst'] = 25;
df.loc[df.texture_worst ==17 ,'texture_worst'] = 26;
df.loc[df.texture_worst ==31 ,'texture_worst'] = 22;
df.loc[df.texture_worst ==20 ,'texture_worst'] = 19;
df.loc[df.texture_worst ==30 ,'texture_worst'] = 19;

df.loc[df.texture_worst ==15 ,'texture_worst'] = 25;
df.loc[df.texture_worst ==33 ,'texture_worst'] = 26;
df.loc[df.texture_worst ==32 ,'texture_worst'] = 22;
df.loc[df.texture_worst ==16 ,'texture_worst'] = 19;
df.loc[df.texture_worst ==18 ,'texture_worst'] = 19;

df.loc[df.texture_worst ==38 ,'texture_worst'] = 25;
df.loc[df.texture_worst ==37 ,'texture_worst'] = 26;
df.loc[df.texture_worst ==36 ,'texture_worst'] = 22;
df.loc[df.texture_worst ==35 ,'texture_worst'] = 19;
df.loc[df.texture_worst ==34 ,'texture_worst'] = 19;

df.loc[df.texture_worst ==44 ,'texture_worst'] = 25;
df.loc[df.texture_worst ==41 ,'texture_worst'] = 26;
df.loc[df.texture_worst ==39 ,'texture_worst'] = 22;
df.loc[df.texture_worst ==14 ,'texture_worst'] = 19;
df.loc[df.texture_worst ==12 ,'texture_worst'] = 19;

df.loc[df.texture_worst ==42 ,'texture_worst'] = 25;
df.loc[df.texture_worst ==47 ,'texture_worst'] = 26;
df.loc[df.texture_worst ==49 ,'texture_worst'] = 22;
df.loc[df.texture_worst ==45 ,'texture_worst'] = 19;
df.loc[df.texture_worst ==40 ,'texture_worst'] = 19;

# %%
df.loc[df.area_se ==23 ,'area_se'] = 20;
df.loc[df.area_se ==16 ,'area_se'] = 19;
df.loc[df.area_se ==20 ,'area_se'] = 18;
df.loc[df.area_se ==14 ,'area_se'] = 17;
df.loc[df.area_se ==22 ,'area_se'] = 17;

df.loc[df.area_se ==24 ,'area_se'] = 20;
df.loc[df.area_se ==12 ,'area_se'] = 19;
df.loc[df.area_se ==15 ,'area_se'] = 18;
df.loc[df.area_se ==14 ,'area_se'] = 17;
df.loc[df.area_se ==22 ,'area_se'] = 17;

df.loc[df.area_se ==28 ,'area_se'] = 20;
df.loc[df.area_se ==27 ,'area_se'] = 19;
df.loc[df.area_se ==13 ,'area_se'] = 18;
df.loc[df.area_se ==11 ,'area_se'] = 17;
df.loc[df.area_se ==21 ,'area_se'] = 17;

df.loc[df.area_se ==9 ,'area_se'] = 20;
df.loc[df.area_se ==33 ,'area_se'] = 19;
df.loc[df.area_se ==29 ,'area_se'] = 18;
df.loc[df.area_se ==26 ,'area_se'] = 17;
df.loc[df.area_se ==25 ,'area_se'] = 17;

# %%
df.loc[df.area_se ==67 ,'area_se'] = 20;
df.loc[df.area_se ==30 ,'area_se'] = 19;
df.loc[df.area_se ==32 ,'area_se'] = 18;
df.loc[df.area_se ==34 ,'area_se'] = 17;
df.loc[df.area_se ==31 ,'area_se'] = 17;

df.loc[df.area_se ==49 ,'area_se'] = 20;
df.loc[df.area_se ==10 ,'area_se'] = 19;
df.loc[df.area_se ==45 ,'area_se'] = 18;
df.loc[df.area_se ==44 ,'area_se'] = 17;
df.loc[df.area_se ==43 ,'area_se'] = 17;

df.loc[df.area_se ==41 ,'area_se'] = 20;
df.loc[df.area_se ==48 ,'area_se'] = 19;
df.loc[df.area_se ==39 ,'area_se'] = 18;
df.loc[df.area_se ==35 ,'area_se'] = 17;
df.loc[df.area_se ==8 ,'area_se'] = 17;

df.loc[df.area_se ==38 ,'area_se'] = 20;
df.loc[df.area_se ==52 ,'area_se'] = 19;
df.loc[df.area_se ==40 ,'area_se'] = 18;
df.loc[df.area_se ==54 ,'area_se'] = 17;
df.loc[df.area_se ==36 ,'area_se'] = 17;

# %%
df.loc[df.area_se ==7 ,'area_se'] = 20;
df.loc[df.area_se ==87 ,'area_se'] = 19;
df.loc[df.area_se ==69 ,'area_se'] = 18;
df.loc[df.area_se ==58 ,'area_se'] = 17;
df.loc[df.area_se ==81 ,'area_se'] = 17;

df.loc[df.area_se ==50 ,'area_se'] = 20;
df.loc[df.area_se ==53 ,'area_se'] = 19;
df.loc[df.area_se ==93 ,'area_se'] = 18;
df.loc[df.area_se ==68 ,'area_se'] = 17;
df.loc[df.area_se ==74 ,'area_se'] = 17;

df.loc[df.area_se ==59 ,'area_se'] = 20;
df.loc[df.area_se ==70 ,'area_se'] = 19;
df.loc[df.area_se ==94 ,'area_se'] = 18;
df.loc[df.area_se ==83 ,'area_se'] = 17;
df.loc[df.area_se ==97 ,'area_se'] = 17;

# %%
df.loc[df.area_se ==102 ,'area_se'] = 20;
df.loc[df.area_se ==103 ,'area_se'] = 19;
df.loc[df.area_se ==130 ,'area_se'] = 18;
df.loc[df.area_se ==77 ,'area_se'] = 17;
df.loc[df.area_se ==37 ,'area_se'] = 17;

df.loc[df.area_se ==111 ,'area_se'] = 20;
df.loc[df.area_se ==116 ,'area_se'] = 19;
df.loc[df.area_se ==90 ,'area_se'] = 18;
df.loc[df.area_se ==80 ,'area_se'] = 17;
df.loc[df.area_se ==63 ,'area_se'] = 17;

df.loc[df.area_se ==153 ,'area_se'] = 20;
df.loc[df.area_se ==60 ,'area_se'] = 19;
df.loc[df.area_se ==71 ,'area_se'] = 18;
df.loc[df.area_se ==104 ,'area_se'] = 17;
df.loc[df.area_se ==106 ,'area_se'] = 17;

# %%
df.loc[df.area_se ==89 ,'area_se'] = 20;
df.loc[df.area_se ==542 ,'area_se'] = 19;
df.loc[df.area_se ==115 ,'area_se'] = 18;
df.loc[df.area_se ==56 ,'area_se'] = 17;
df.loc[df.area_se ==57 ,'area_se'] = 17;

df.loc[df.area_se ==95 ,'area_se'] = 20;
df.loc[df.area_se ==66 ,'area_se'] = 19;
df.loc[df.area_se ==6 ,'area_se'] = 18;
df.loc[df.area_se ==176 ,'area_se'] = 17;
df.loc[df.area_se ==72 ,'area_se'] = 17;


df.loc[df.area_se ==75 ,'area_se'] = 20;
df.loc[df.area_se ==170 ,'area_se'] = 19;
df.loc[df.area_se ==164 ,'area_se'] = 18;
df.loc[df.area_se ==51 ,'area_se'] = 17;
df.loc[df.area_se ==224 ,'area_se'] = 17;


df.loc[df.area_se ==180 ,'area_se'] = 20;
df.loc[df.area_se ==122 ,'area_se'] = 19;
df.loc[df.area_se ==128 ,'area_se'] = 18;
df.loc[df.area_se ==112 ,'area_se'] = 17;
df.loc[df.area_se ==88 ,'area_se'] = 17;

df.loc[df.area_se ==139 ,'area_se'] = 20;
df.loc[df.area_se ==101 ,'area_se'] = 19;
df.loc[df.area_se ==46 ,'area_se'] = 18;
df.loc[df.area_se ==120 ,'area_se'] = 17;
df.loc[df.area_se ==134 ,'area_se'] = 17;

df.loc[df.area_se ==100 ,'area_se'] = 20;
df.loc[df.area_se ==76 ,'area_se'] = 19;
df.loc[df.area_se ==96 ,'area_se'] = 18;
df.loc[df.area_se ==119 ,'area_se'] = 17;
df.loc[df.area_se ==79 ,'area_se'] = 17;

df.loc[df.area_se ==118 ,'area_se'] = 20;
df.loc[df.area_se ==133 ,'area_se'] = 19;
df.loc[df.area_se ==233 ,'area_se'] = 18;
df.loc[df.area_se ==525 ,'area_se'] = 17;
df.loc[df.area_se ==98 ,'area_se'] = 17;

df.loc[df.area_se ==158 ,'area_se'] = 20;
df.loc[df.area_se ==199 ,'area_se'] = 19;
df.loc[df.area_se ==105 ,'area_se'] = 18;
df.loc[df.area_se ==109 ,'area_se'] = 17;
df.loc[df.area_se ==124 ,'area_se'] = 17;

df.loc[df.area_se ==99 ,'area_se'] = 20;
df.loc[df.area_se ==156 ,'area_se'] = 19;
df.loc[df.area_se ==42 ,'area_se'] = 18;
df.loc[df.area_se ==138 ,'area_se'] = 17;
df.loc[df.area_se ==61 ,'area_se'] = 17;

df.loc[df.area_se ==155 ,'area_se'] = 20;
df.loc[df.area_se ==137 ,'area_se'] = 19;
df.loc[df.area_se ==92 ,'area_se'] = 18;
df.loc[df.area_se ==47 ,'area_se'] = 17;
df.loc[df.area_se ==86 ,'area_se'] = 17;

# %%
df.loc[df.texture_se ==4 ,'texture_se'] = 2;
df.loc[df.texture_se ==3 ,'texture_se'] = 2;
df.loc[df.texture_se ==2 ,'texture_se'] = 0;

# %%
df.loc[df.radius_mean ==28 ,'radius_mean'] = 12;
df.loc[df.radius_mean ==6 ,'radius_mean'] = 13;
df.loc[df.radius_mean ==27 ,'radius_mean'] = 12;
df.loc[df.radius_mean ==24 ,'radius_mean'] = 12;
df.loc[df.radius_mean ==22 ,'radius_mean'] = 12;
df.loc[df.radius_mean ==25 ,'radius_mean'] = 12;
df.loc[df.radius_mean ==7 ,'radius_mean'] = 12;
df.loc[df.radius_mean ==23 ,'radius_mean'] = 13;
df.loc[df.radius_mean ==21 ,'radius_mean'] = 12;
df.loc[df.radius_mean ==8 ,'radius_mean'] = 12;
df.loc[df.radius_mean ==18 ,'radius_mean'] = 12;
df.loc[df.radius_mean ==16 ,'radius_mean'] = 12;

df.loc[df.radius_mean ==20 ,'radius_mean'] = 11;
df.loc[df.radius_mean ==17 ,'radius_mean'] = 13;
df.loc[df.radius_mean ==19 ,'radius_mean'] = 10;
df.loc[df.radius_mean ==9 ,'radius_mean'] = 15;
df.loc[df.radius_mean ==14 ,'radius_mean'] = 15;
df.loc[df.radius_mean ==10 ,'radius_mean'] = 11;

# %%
df['perimeter_mean'].value_counts()
# Out:
# perimeter_mean
# 73     20
# 82     20
# 78     20
# 88     18
# 87     17
#        ..
# 158     1
# 125     1
# 153     1
# 188     1
# 48      1
# Name: count, Length: 105, dtype: int64

# %%
df.loc[df.perimeter_mean ==94,'perimeter_mean'] = 73;
df.loc[df.perimeter_mean ==87 ,'perimeter_mean'] = 82;
df.loc[df.perimeter_mean ==84,'perimeter_mean'] = 73;
df.loc[df.perimeter_mean ==81 ,'perimeter_mean'] = 82;
df.loc[df.perimeter_mean ==76 ,'perimeter_mean'] = 78;
df.loc[df.perimeter_mean ==97 ,'perimeter_mean'] = 73;
df.loc[df.perimeter_mean ==77 ,'perimeter_mean'] = 87;

df.loc[df.perimeter_mean ==74,'perimeter_mean'] = 73;
df.loc[df.perimeter_mean ==75 ,'perimeter_mean'] = 82;
df.loc[df.perimeter_mean ==71 ,'perimeter_mean'] = 78;
df.loc[df.perimeter_mean ==70 ,'perimeter_mean'] = 88;
df.loc[df.perimeter_mean ==85 ,'perimeter_mean'] = 87;

df.loc[df.perimeter_mean ==79,'perimeter_mean'] = 73;
df.loc[df.perimeter_mean ==102 ,'perimeter_mean'] = 82;
df.loc[df.perimeter_mean ==96 ,'perimeter_mean'] = 78;
df.loc[df.perimeter_mean ==97 ,'perimeter_mean'] = 88;
df.loc[df.perimeter_mean ==77 ,'perimeter_mean'] = 87;

# %%
df.loc[df.perimeter_mean ==86,'perimeter_mean'] = 73;
df.loc[df.perimeter_mean ==68 ,'perimeter_mean'] = 82;
df.loc[df.perimeter_mean ==61 ,'perimeter_mean'] = 78;
df.loc[df.perimeter_mean ==79 ,'perimeter_mean'] = 88;
df.loc[df.perimeter_mean ==83 ,'perimeter_mean'] = 87;

df.loc[df.perimeter_mean ==66,'perimeter_mean'] = 73;
df.loc[df.perimeter_mean ==92 ,'perimeter_mean'] = 82;
df.loc[df.perimeter_mean ==90 ,'perimeter_mean'] = 78;
df.loc[df.perimeter_mean ==98 ,'perimeter_mean'] = 88;
df.loc[df.perimeter_mean ==83 ,'perimeter_mean'] = 87;

df.loc[df.perimeter_mean ==89,'perimeter_mean'] = 73;
df.loc[df.perimeter_mean ==103 ,'perimeter_mean'] = 82;
df.loc[df.perimeter_mean ==65 ,'perimeter_mean'] = 78;
df.loc[df.perimeter_mean ==130 ,'perimeter_mean'] = 88;
df.loc[df.perimeter_mean ==59 ,'perimeter_mean'] = 87;

# %%
df.loc[df.perimeter_mean ==63,'perimeter_mean'] = 73;
df.loc[df.perimeter_mean ==72 ,'perimeter_mean'] = 82;
df.loc[df.perimeter_mean ==80 ,'perimeter_mean'] = 78;
df.loc[df.perimeter_mean ==93 ,'perimeter_mean'] = 88;
df.loc[df.perimeter_mean ==95 ,'perimeter_mean'] = 87;

df.loc[df.perimeter_mean ==129,'perimeter_mean'] = 73;
df.loc[df.perimeter_mean ==132 ,'perimeter_mean'] = 82;
df.loc[df.perimeter_mean ==64 ,'perimeter_mean'] = 78;
df.loc[df.perimeter_mean ==117 ,'perimeter_mean'] = 88;
df.loc[df.perimeter_mean ==114 ,'perimeter_mean'] = 87;

df.loc[df.perimeter_mean ==120 ,'perimeter_mean'] = 73;
df.loc[df.perimeter_mean ==60 ,'perimeter_mean'] = 82;
df.loc[df.perimeter_mean ==134 ,'perimeter_mean'] = 78;
df.loc[df.perimeter_mean ==91 ,'perimeter_mean'] = 88;
df.loc[df.perimeter_mean ==109 ,'perimeter_mean'] = 87;

df.loc[df.perimeter_mean ==100 ,'perimeter_mean'] = 73;
df.loc[df.perimeter_mean ==128 ,'perimeter_mean'] = 82;
df.loc[df.perimeter_mean ==106 ,'perimeter_mean'] = 78;
df.loc[df.perimeter_mean ==107 ,'perimeter_mean'] = 88;
df.loc[df.perimeter_mean ==54 ,'perimeter_mean'] = 87;

# %%
df.loc[df.perimeter_mean ==127 ,'perimeter_mean'] = 73;
df.loc[df.perimeter_mean ==111 ,'perimeter_mean'] = 82;
df.loc[df.perimeter_mean ==133 ,'perimeter_mean'] = 78;
df.loc[df.perimeter_mean ==108 ,'perimeter_mean'] = 88;
df.loc[df.perimeter_mean ==123 ,'perimeter_mean'] = 87;

df.loc[df.perimeter_mean ==122 ,'perimeter_mean'] = 73;
df.loc[df.perimeter_mean ==115 ,'perimeter_mean'] = 82;
df.loc[df.perimeter_mean ==137 ,'perimeter_mean'] = 78;
df.loc[df.perimeter_mean ==113 ,'perimeter_mean'] = 88;
df.loc[df.perimeter_mean ==105 ,'perimeter_mean'] = 87;

df.loc[df.perimeter_mean ==135 ,'perimeter_mean'] = 73;
df.loc[df.perimeter_mean ==104 ,'perimeter_mean'] = 82;
df.loc[df.perimeter_mean ==62 ,'perimeter_mean'] = 78;
df.loc[df.perimeter_mean ==69 ,'perimeter_mean'] = 88;
df.loc[df.perimeter_mean ==121 ,'perimeter_mean'] = 87;

df.loc[df.perimeter_mean ==118 ,'perimeter_mean'] = 73;
df.loc[df.perimeter_mean ==67 ,'perimeter_mean'] = 82;
df.loc[df.perimeter_mean ==126 ,'perimeter_mean'] = 78;
df.loc[df.perimeter_mean ==152 ,'perimeter_mean'] = 88;
df.loc[df.perimeter_mean ==110 ,'perimeter_mean'] = 87;

df.loc[df.perimeter_mean ==58 ,'perimeter_mean'] = 73;
df.loc[df.perimeter_mean ==142 ,'perimeter_mean'] = 82;
df.loc[df.perimeter_mean ==116 ,'perimeter_mean'] = 78;
df.loc[df.perimeter_mean ==143 ,'perimeter_mean'] = 88;
df.loc[df.perimeter_mean ==138 ,'perimeter_mean'] = 88;

df.loc[df.perimeter_mean ==124 ,'perimeter_mean'] = 73;
df.loc[df.perimeter_mean ==112 ,'perimeter_mean'] = 82;
df.loc[df.perimeter_mean ==101 ,'perimeter_mean'] = 78;
df.loc[df.perimeter_mean ==140 ,'perimeter_mean'] = 88;


df.loc[df.perimeter_mean ==47 ,'perimeter_mean'] = 73;
df.loc[df.perimeter_mean ==51 ,'perimeter_mean'] = 82;
df.loc[df.perimeter_mean ==155 ,'perimeter_mean'] = 78;
df.loc[df.perimeter_mean ==174 ,'perimeter_mean'] = 88;
df.loc[df.perimeter_mean ==141 ,'perimeter_mean'] = 88;

df.loc[df.perimeter_mean ==182 ,'perimeter_mean'] = 73;
df.loc[df.perimeter_mean ==166 ,'perimeter_mean'] = 82;
df.loc[df.perimeter_mean ==99 ,'perimeter_mean'] = 78;
df.loc[df.perimeter_mean ==53 ,'perimeter_mean'] = 88;
df.loc[df.perimeter_mean ==171 ,'perimeter_mean'] = 88;

df.loc[df.perimeter_mean ==158 ,'perimeter_mean'] = 73;
df.loc[df.perimeter_mean ==125 ,'perimeter_mean'] = 82;
df.loc[df.perimeter_mean ==153 ,'perimeter_mean'] = 78;
df.loc[df.perimeter_mean ==188 ,'perimeter_mean'] = 88;

df.loc[df.perimeter_mean ==186 ,'perimeter_mean'] = 73;
df.loc[df.perimeter_mean ==165 ,'perimeter_mean'] = 82;
df.loc[df.perimeter_mean ==43 ,'perimeter_mean'] = 78;
df.loc[df.perimeter_mean ==48 ,'perimeter_mean'] = 88;
df.loc[df.perimeter_mean ==144 ,'perimeter_mean'] = 88;

df.loc[df.perimeter_mean ==88 ,'perimeter_mean'] = 73;
df.loc[df.perimeter_mean ==55 ,'perimeter_mean'] = 82;
df.loc[df.perimeter_mean ==167 ,'perimeter_mean'] = 78;
df.loc[df.perimeter_mean ==56 ,'perimeter_mean'] = 73;
df.loc[df.perimeter_mean ==131 ,'perimeter_mean'] = 78;
df.loc[df.perimeter_mean ==119 ,'perimeter_mean'] = 73;
df.loc[df.perimeter_mean ==147 ,'perimeter_mean'] = 73;

df.loc[df.perimeter_mean ==87 ,'perimeter_mean'] = 78;
df.loc[df.radius_se ==2 ,'radius_se'] = 1;
df.loc[df.area_se ==20 ,'area_se'] = 19;

# %%
df.loc[df.area_worst ==437 ,'area_worst'] = 709;
df.loc[df.area_worst ==579 ,'area_worst'] = 830;
df.loc[df.area_worst ==600 ,'area_worst'] = 709;
df.loc[df.area_worst ==1210 ,'area_worst'] = 830;
df.loc[df.area_worst ==1437 ,'area_worst'] = 709;
df.loc[df.area_worst ==812 ,'area_worst'] = 830;
df.loc[df.texture_worst ==26 ,'texture_worst'] = 22;

# %%
df.columns
# Out:
# Index(['diagnosis', 'radius_mean', 'perimeter_mean', 'concave points_mean',
#        'fractal_dimension_mean', 'radius_se', 'texture_se', 'area_se',
#        'concavity_se', 'concave points_se', 'texture_worst', 'perimeter_worst',
#        'area_worst', 'compactness_worst'],
#       dtype='object')

# %%
df['compactness_worst'].value_counts()
# Out:
# compactness_worst
# 0    568
# 1      1
# Name: count, dtype: int64

# %%
df.dtypes
# Out:
# diagnosis                 int64
# radius_mean               int64
# perimeter_mean            int64
# concave points_mean       int64
# fractal_dimension_mean    int64
# radius_se                 int64
# texture_se                int64
# area_se                   int64
# concavity_se              int64
# concave points_se         int64
# texture_worst             int64
# perimeter_worst           int64
# area_worst                int64
# compactness_worst         int64
# dtype: object

# %%
df.columns
# Out:
# Index(['diagnosis', 'radius_mean', 'perimeter_mean', 'concave points_mean',
#        'fractal_dimension_mean', 'radius_se', 'texture_se', 'area_se',
#        'concavity_se', 'concave points_se', 'texture_worst', 'perimeter_worst',
#        'area_worst', 'compactness_worst'],
#       dtype='object')

# %%
df['concave points_mean'].value_counts()
# Out:
# concave points_mean
# 0    533
# 1     36
# Name: count, dtype: int64

# %%
df
# Out:
#      diagnosis  radius_mean  perimeter_mean  concave points_mean  \
# 0            1           13              73                    1
# 1            1           11              82                    1
# 2            1           11              73                    1
# 3            1           11              78                    1
# 4            1           11              73                    1
# ..         ...          ...             ...                  ...
# 564          1           12              82                    0
# 565          1           11              78                    0
# 566          1           12              73                    0
# 567          1           11              73                    0
# 568          0           12              73                    0
#
#      fractal_dimension_mean  radius_se  texture_se  area_se  concavity_se  \
# 0                         1          1           0       19             1
# ...

# %%
X=df.drop('diagnosis',axis=1)
y=df.diagnosis

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, shuffle=True, random_state=42)

# %%
from sklearn.ensemble import RandomForestClassifier
model = RandomForestClassifier(criterion='entropy',max_features='sqrt',min_samples_split=3,n_estimators=500,random_state=0,max_depth=20, max_leaf_nodes=400, n_jobs=-1)
model.fit(X_train,y_train)
y_predict = model.predict(X_test)

# %%
from sklearn.metrics import mean_absolute_error, r2_score
print("MAE : ", mean_absolute_error(y_test,y_predict))
r2_score(y_test,y_predict)
# Out:
# MAE :  0.3157894736842105
# -0.3442515558467083

# %%
import sklearn as extjoblib
import joblib
import pickle

# %%
joblib.dump(model,'C:/Users/Dawit Shibabaw/Desktop/Dawit/Breast_cancer.ml')
# Out:
# ['C:/Users/Dawit Shibabaw/Desktop/Dawit/Breast_cancer.ml']

# %%
import pickle
# Lets dump our SVM model
pickle.dump(model, open('C:/Users/Dawit Shibabaw/Desktop/Dawit/Breast_cancer.pkl','wb'))
